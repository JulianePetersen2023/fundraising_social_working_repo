# %%
import pandas as pd

# %%
df = pd.read_csv('Social_enterpreneurship_dataset.csv')
df[['project_name']].head(60)
# Out:
#                                          project_name
# 0     Bianca Nikol Roberson Mural: STOP GUN VIOLENCE!
# 1             Help People with a Disability in Maleny
# 2       You Can Help Us Launch The Priceless Campaign
# 3   "It is not the mountain we conquer but ourselv...
# 4                #APATCE - Empowering Tourism for All
# 5            #BlackandHooded Scholarship Fund 2018-19
# 6                                    #SwipeItForward
# 7                                   1 in Too Campaign
# 8            10 For 10 - Help charities drive impact!
# 9                       100 Miles to End Homelessness
# 10                      1000 Hummingbirds Water Women
# 11                      1000 Hummingbirds Water Women
# 12                      1000 Hummingbirds Water Women
# 13      2000 Schools To Help Save Our Black Cockatoos
# 14          2014 Native American Heritage Day Concert
# 15               2017 Denis Tricks Leader Scholarship
# ...

# %%
df.columns.value_counts()
# Out:
# project_name    1
# insight         1
# relativ         1
# focusfuture     1
# focuspresent    1
#                ..
# adverb          1
# auxverb         1
# prep            1
# article         1
# OtherP          1
# Name: count, Length: 105, dtype: int64

# %%
df.isna().sum().head(50)
# Out:
# project_name           0
# project_location       0
# project_founder        0
# fund_goal              0
# fund_currency          0
# fund_progress          0
# fund_date_end          0
# fund_supporter         6
# category               1
# goal_tipping point     0
# goal_stretch point     0
# percentagefunded       0
# percstretch            0
# Word_count            36
# Analytic              36
# Clout                 36
# Authentic             36
# Tone                  36
# Words_per_sentence    36
# Sixltr                36
# function              36
# pronoun               36
# ppron                 36
# i                     36
# we                    36
# you                   36
# shehe                 36
# they                  36
# ipron                 36
# article               36
# prep                  36
# auxverb               36
# adverb                36
# conj                  36
# negate                36
# verb                  36
# adj                   36
# ...

# %%
df.columns
# Out:
# Index(['project_name', 'project_location', 'project_founder', 'fund_goal',
#        'fund_currency', 'fund_progress', 'fund_date_end', 'fund_supporter',
#        'category', 'goal_tipping point',
#        ...
#        'Comma', 'Colon', 'SemiC', 'QMark', 'Exclam', 'Dash', 'Quote',
#        'Apostro', 'Parenth', 'OtherP'],
#       dtype='object', length=105)

# %%
df.head(25)
# Out:
#                                          project_name  \
# 0     Bianca Nikol Roberson Mural: STOP GUN VIOLENCE!
# 1             Help People with a Disability in Maleny
# 2       You Can Help Us Launch The Priceless Campaign
# 3   "It is not the mountain we conquer but ourselv...
# 4                #APATCE - Empowering Tourism for All
# 5            #BlackandHooded Scholarship Fund 2018-19
# 6                                    #SwipeItForward
# 7                                   1 in Too Campaign
# 8            10 For 10 - Help charities drive impact!
# 9                       100 Miles to End Homelessness
# 10                      1000 Hummingbirds Water Women
# 11                      1000 Hummingbirds Water Women
# 12                      1000 Hummingbirds Water Women
# 13      2000 Schools To Help Save Our Black Cockatoos
# 14          2014 Native American Heritage Day Concert
# 15               2017 Denis Tricks Leader Scholarship
# ...
